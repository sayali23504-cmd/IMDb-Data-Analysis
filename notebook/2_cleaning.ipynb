# %%
import pandas as pd
import numpy as np
df = pd.read_csv("../Raw data/imdb_top_1000.csv")

# %%
print(df.isnull().sum())
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df=(df.dropna())
print(df)
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 990  https://m.media-amazon.com/images/M/MV5BYjRmY2...
# 991  https://m.media-amazon.com/images/M/MV5BMzAyND...
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# 994  https://m.media-amazon.com/images/M/MV5BZjQyMG...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
print(df.isnull().sum())
# Out:
# Poster_Link      0
# Series_Title     0
# Released_Year    0
# Certificate      0
# Runtime          0
# Genre            0
# IMDB_Rating      0
# Overview         0
# Meta_score       0
# Director         0
# Star1            0
# Star2            0
# Star3            0
# Star4            0
# No_of_Votes      0
# Gross            0
# dtype: int64

# %%
df.shape
# Out:
# (714, 16)

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df.dtypes
# Out:
# Poster_Link          str
# Series_Title         str
# Released_Year        str
# Certificate          str
# Runtime              str
# Genre                str
# IMDB_Rating      float64
# Overview             str
# Meta_score       float64
# Director             str
# Star1                str
# Star2                str
# Star3                str
# Star4                str
# No_of_Votes        int64
# Gross                str
# dtype: object

# %%
#issues with runtime- int, released yr- int, runtime- int, gross- remove commas
df["Released_Year"].unique()
# Out:
# <StringArray>
# ['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010', '1999',
#  '2001', '1966', '2002', '1990', '1980', '1975', '2019', '2014', '1998',
#  '1997', '1995', '1991', '1977', '1954', '2011', '2006', '2000', '1988',
#  '1985', '1968', '1960', '1942', '1936', '1931', '2018', '2016', '2017',
#  '2012', '2009', '1981', '1979', '1964', '2004', '1992', '1987', '1986',
#  '1984', '1983', '1976', '1973', '1971', '1965', '1962', '1959', '1958',
#  '1952', '1944', '1941', '2013', '2007', '2005', '1989', '1963', '1950',
#  '1948', '2015', '1996', '1982', '1978', '1967', '1951', '1949', '1940',
#  '1939', '1934', '1970', '1969', '1961', '1946', '1930', '1938', '1933',
#    'PG', '1953']
# Length: 83, dtype: str

# %%
#to find the problem- 
df[~df["Released_Year"].str.isnumeric()]
# Out:
#                                            Poster_Link Series_Title  \
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
#
#     Released_Year Certificate  Runtime                      Genre  \
# 966            PG           U  140 min  Adventure, Drama, History
#
#      IMDB_Rating                                           Overview  \
# 966          7.6  NASA must devise a strategy to return Apollo 1...
#
#      Meta_score    Director      Star1        Star2        Star3        Star4  \
# 966        77.0  Ron Howard  Tom Hanks  Bill Paxton  Kevin Bacon  Gary Sinise
#
#      No_of_Votes        Gross
# 966       269197  173,837,933

# %%
#correct the value
df.loc[df["Released_Year"]=="PG", "Released_Year"]="1995"
df[df["Series_Title"]=="Apollo 13"]
# Out:
#                                            Poster_Link Series_Title  \
# 966  https://m.media-amazon.com/images/M/MV5BNjEzYj...    Apollo 13
#
#     Released_Year Certificate  Runtime                      Genre  \
# 966          1995           U  140 min  Adventure, Drama, History
#
#      IMDB_Rating                                           Overview  \
# 966          7.6  NASA must devise a strategy to return Apollo 1...
#
#      Meta_score    Director      Star1        Star2        Star3        Star4  \
# 966        77.0  Ron Howard  Tom Hanks  Bill Paxton  Kevin Bacon  Gary Sinise
#
#      No_of_Votes        Gross
# 966       269197  173,837,933

# %%
#change dtype
df["Released_Year"]= df["Released_Year"].astype(int)
print(df["Released_Year"].dtype)
# Out:
# int64

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df["Runtime"] = df["Runtime"].str.replace(" min", "", regex=False)

# %%
df["Runtime"].head
# Out:
# <bound method NDFrame.head of 0      142
# 1      175
# 2      152
# 3      202
# 4       96
#       ...
# 990    157
# 991    144
# 992     78
# 994     87
# 997    118
# Name: Runtime, Length: 714, dtype: str>

# %%
df["Runtime"] = df["Runtime"].astype(int)

# %%
df["Gross"]= df["Gross"].str.replace(",","", regex=False)
df["Gross"].head(2)
# Out:
# 0     28341469
# 1    134966411
# Name: Gross, dtype: str

# %%
df["Gross"] = df["Gross"].astype(int)

# %%
df.to_csv("../Data/Cleaned data/imdb_cleaned.csv", index=False)

# %%
print(df.shape)
print(df["Gross"].isna().sum())
print(df["Gross"].dtype)
# Out:
# (714, 16)
# 0
# int64
